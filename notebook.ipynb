# %% [markdown]
# ### DATA SCIENTIST JOB RECOMMENDER SYSTEM

# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv', on_bad_lines='skip', sep=",", encoding='cp1252')
df
# Out:
#       Unnamed: 0                                                URL  \
# 0              1  https://www.glassdoor.com/job-listing/data-sci...
# 1              2  https://www.glassdoor.com/job-listing/machine-...
# 2              3  https://www.glassdoor.com/job-listing/data-sci...
# 3              4  https://www.glassdoor.com/job-listing/data-sci...
# 4              5  https://www.glassdoor.com/job-listing/data-ana...
# ...          ...                                                ...
# 1080        1081  https://www.glassdoor.com/job-listing/research...
# 1081        1082  https://www.glassdoor.com/job-listing/call-cen...
# 1082        1083  https://www.glassdoor.com/job-listing/usmtf-da...
# 1083        1084  https://www.glassdoor.com/job-listing/engineer...
# 1084        1085  https://www.glassdoor.com/job-listing/c-wwl-da...
#
#                                             Description  \
# 0     Indeed Prime is a free service that connects q...
# 1     Position Summary: Machine Learning researchers...
# 2                                                   NaN
# 3      Support data-driven product decisions that im...
# 4     Bechtel Plant Machinery, Inc. (BPMI) is seekin...
# ...                                                 ...
# 1080  Research Scientist:Aeroacoustics The National ...
# 1081  Title Call Center Data Analyst  16-Nov-2018 De...
# 1082   OverviewOasis Systems has an exciting opportu...
# 1083  Engineer/Scientist 2 (Mechanical) - Navigation...
# 1084  Position: WWL Data Analyst III - 150466Locatio...
#
#                                              Job_Title  Company_Rating  \
# 0                                                  NaN             NaN
# 1     Machine Learning Research Scientist (Entry-Level             3.3
# 2                                     Data Scientist I             2.7
# 3                                  Data Science Intern             4.9
# 4                                         Data Analyst             3.5
# ...                                                ...             ...
# 1080                 RESEARCH SCIENTIST: Aeroacoustics             3.1
# 1081                          Call Center Data Analyst             2.9
# 1082                                USMTF Data Analyst             3.2
# 1083    Engineer/Scientist 2 (Mechanical) - Navigation             3.2
# 1084                                               NaN             NaN
#
#                           Company_Name    Company_Location Estimated_Salary  \
# 0                                  NaN                 NaN              NaN
# 1       Software Engineering Institute    – Pittsburgh, PA    $92,000/ year
# 2                  United States Steel    – Pittsburgh, PA   $126,000/ year
# 3                             Duolingo    – Pittsburgh, PA              NaN
# 4                                 BPMI   – Monroeville, PA    $48,000/ year
# ...                                ...                 ...              ...
# 1080   National Institute of Aerospace       – Hampton, VA    $73,000/ year
# 1081                       Dollar Tree    – Chesapeake, VA    $59,000/ year
# 1082                 MAR, Incorporated       – Hampton, VA    $63,000/ year
# 1083                   L3 Technologies       – Norfolk, VA              NaN
# 1084                               NaN                 NaN              NaN
#
#       Location_Code
# 0           1152990
# 1           1152990
# 2           1152990
# 3           1152990
# 4           1152990
# ...             ...
# 1080        1130324
# 1081        1130324
# 1082        1130324
# 1083        1130324
# 1084        1130324
#
# [1085 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'URL', 'Description', 'Job_Title', 'Company_Rating',
#        'Company_Name', 'Company_Location', 'Estimated_Salary',
#        'Location_Code'],
#       dtype='object')

# %%
df.Company_Location.unique()
# Out:
# array([nan, '\xa0–\xa0Pittsburgh, PA', '\xa0–\xa0Monroeville, PA',
#        '\xa0–\xa0Coraopolis, PA', '\xa0–\xa0Blue Bell, PA',
#        '\xa0–\xa0Dresher, PA', '\xa0–\xa0Philadelphia, PA',
#        '\xa0–\xa0King of Prussia, PA', '\xa0–\xa0Newtown Square, PA',
#        '\xa0–\xa0Exton, PA', '\xa0–\xa0Malvern, PA',
#        '\xa0–\xa0Kulpsville, PA', '\xa0–\xa0Radnor, PA',
#        '\xa0–\xa0Ambler, PA', '\xa0–\xa0Berwyn, PA',
#        '\xa0–\xa0Brooklyn, NY', '\xa0–\xa0New York, NY',
#        '\xa0–\xa0Boston, MA', '\xa0–\xa0Cambridge, MA',
#        '\xa0–\xa0Andover, MA', '\xa0–\xa0Bedford, MA',
#        '\xa0–\xa0Framingham, MA', '\xa0–\xa0Baltimore, MD',
#        '\xa0–\xa0Laurel, MD', '\xa0–\xa0Timonium, MD',
#        '\xa0–\xa0Annapolis Junction, MD', '\xa0–\xa0Towson, MD',
#        '\xa0–\xa0Columbia, MD', '\xa0–\xa0Hunt Valley, MD',
#        '\xa0–\xa0Sparks, MD', '\xa0–\xa0Hanover, MD',
#        '\xa0–\xa0Linthicum Heights, MD', '\xa0–\xa0Fort Meade, MD',
#        '\xa0–\xa0Elkridge, MD', '\xa0–\xa0Washington, DC',
#        '\xa0–\xa0Arlington, VA', '\xa0–\xa0McLean, VA',
#        '\xa0–\xa0Reston, VA', '\xa0–\xa0Rosslyn, VA',
#        '\xa0–\xa0Crystal City, VA', '\xa0–\xa0Springfield, VA',
#        '\xa0–\xa0Fairfax, VA', '\xa0–\xa0Durham, NC',
#        '\xa0–\xa0Raleigh, NC', '\xa0–\xa0Cary, NC',
#        '\xa0–\xa0Morrisville, NC', '\xa0–\xa0Research Triangle Park, NC',
#        '\xa0–\xa0San Francisco, CA', '\xa0–\xa0San Bruno, CA',
#        '\xa0–\xa0Oakland, CA', '\xa0–\xa0Redwood City, CA',
#        '\xa0–\xa0San Mateo, CA', '\xa0–\xa0Mill Valley, CA',
#        '\xa0–\xa0Austin, TX', '\xa0–\xa0Round Rock, TX',
#        '\xa0–\xa0Miami, FL', '\xa0–\xa0Fort Lauderdale, FL',
#        '\xa0–\xa0Miami Lakes, FL', '\xa0–\xa0Miramar, FL',
#        '\xa0–\xa0Plantation, FL', '\xa0–\xa0Pembroke Pines, FL',
#        '\xa0–\xa0Denver, CO', '\xa0–\xa0Golden, CO',
#        '\xa0–\xa0Boulder, CO', '\xa0–\xa0Broomfield, CO',
#        '\xa0–\xa0Thornton, CO', '\xa0–\xa0Arvada, CO',
#        '\xa0–\xa0Englewood, CO', '\xa0–\xa0Buffalo, NY',
#        '\xa0–\xa0Brighton, Erie, NY', '\xa0–\xa0Williamsville, NY',
#        '\xa0–\xa0Grand Island, NY', '\xa0–\xa0Cheektowaga, NY',
#        '\xa0–\xa0Amherst, NY', '\xa0–\xa0Nashville, TN',
#        '\xa0–\xa0Brentwood, TN', '\xa0–\xa0Franklin, TN',
#        '\xa0–\xa0Las Vegas, NV', '\xa0–\xa0North Las Vegas, NV',
#        '\xa0–\xa0Los Angeles, CA', '\xa0–\xa0Glendale, CA',
#        '\xa0–\xa0Santa Monica, CA', '\xa0–\xa0Pasadena, CA',
#        '\xa0–\xa0Torrance, CA', '\xa0–\xa0Playa Vista, CA',
#        '\xa0–\xa0Northridge, CA', '\xa0–\xa0Hollywood, CA',
#        '\xa0–\xa0Universal City, CA', '\xa0–\xa0El Segundo, CA',
#        '\xa0–\xa0Marina del Rey, CA', '\xa0–\xa0San Antonio, TX',
#        '\xa0–\xa0Seattle, WA', '\xa0–\xa0Portland, OR',
#        '\xa0–\xa0Vancouver, WA', '\xa0–\xa0Lake Oswego, OR',
#        '\xa0–\xa0Hillsboro, OR', '\xa0–\xa0Chicago, IL',
#        '\xa0–\xa0Phoenix, AZ', '\xa0–\xa0Tempe, AZ',
#        '\xa0–\xa0Scottsdale, AZ', '\xa0–\xa0Chandler, AZ',
#        '\xa0–\xa0Sun Tech, AZ', '\xa0–\xa0Dallas, TX',
#        '\xa0–\xa0Plano, TX', '\xa0–\xa0Irving, TX',
#        '\xa0–\xa0Richardson, TX', '\xa0–\xa0Allen, TX',
#        '\xa0–\xa0San Diego, CA', '\xa0–\xa0San Jose, CA',
#        '\xa0–\xa0Mountain View, CA', '\xa0–\xa0Santa Clara, CA',
#        '\xa0–\xa0Palo Alto, CA', '\xa0–\xa0Sunnyvale, CA',
#        '\xa0–\xa0Fremont, CA', '\xa0–\xa0Jacksonville, FL',
#        '\xa0–\xa0Columbus, OH', '\xa0–\xa0Reynoldsburg, OH',
#        '\xa0–\xa0Whitehall, OH', '\xa0–\xa0Fort Worth, TX',
#        '\xa0–\xa0Arlington, TX', '\xa0–\xa0Indianapolis, IN',
#        '\xa0–\xa0Carmel, IN', '\xa0–\xa0Charlotte, NC',
#        '\xa0–\xa0Kannapolis, NC', '\xa0–\xa0Fort Mill, SC',
#        '\xa0–\xa0Mooresville, NC', '\xa0–\xa0Sterling Heights, MI',
#        '\xa0–\xa0Northville, MI', '\xa0–\xa0Dearborn, MI',
#        '\xa0–\xa0Detroit, MI', '\xa0–\xa0Livonia, MI',
#        '\xa0–\xa0Troy, MI', '\xa0–\xa0Memphis, TN',
#        '\xa0–\xa0Oklahoma City, OK', '\xa0–\xa0Norman, OK',
#        '\xa0–\xa0Louisville, KY', '\xa0–\xa0Waukesha, WI',
#        '\xa0–\xa0Glendale, WI', '\xa0–\xa0Milwaukee, WI',
#        '\xa0–\xa0Brookfield, WI', '\xa0–\xa0Grafton, WI',
#        '\xa0–\xa0Germantown, WI', '\xa0–\xa0Tucson, AZ',
#        '\xa0–\xa0Twinsburg, OH', '\xa0–\xa0Cleveland, OH',
#        '\xa0–\xa0Highland Heights, Cuyahoga, OH', '\xa0–\xa0Westlake, OH',
#        '\xa0–\xa0Wickliffe, OH',
#        '\xa0–\xa0Mayfield Heights, Cuyahoga, OH',
#        '\xa0–\xa0Brecksville, OH', '\xa0–\xa0Kirtland, OH',
#        '\xa0–\xa0Albuquerque, NM', '\xa0–\xa0West Sacramento, CA',
#        '\xa0–\xa0Sacramento, CA', '\xa0–\xa0Roseville, CA',
#        '\xa0–\xa0Gold River, CA', '\xa0–\xa0Elk Grove, CA',
#        '\xa0–\xa0Olathe, KS', '\xa0–\xa0Kansas City, MO',
#        '\xa0–\xa0North Kansas City, MO', '\xa0–\xa0Mission, KS',
#        '\xa0–\xa0Overland Park, KS', '\xa0–\xa0Shawnee, KS',
#        '\xa0–\xa0Kansas City, KS', '\xa0–\xa0Leawood, KS',
#        '\xa0–\xa0Lenexa, KS', '\xa0–\xa0Atlanta, GA',
#        '\xa0–\xa0Alpharetta, GA', '\xa0–\xa0Norcross, GA',
#        '\xa0–\xa0Foster City, CA', '\xa0–\xa0Emeryville, CA',
#        '\xa0–\xa0Saint Louis, MO', '\xa0–\xa0Rosemont, IL',
#        '\xa0–\xa0Chesterfield, MO', '\xa0–\xa0Herndon, VA',
#        '\xa0–\xa0Lake Mary, FL', '\xa0–\xa0Orlando, FL',
#        '\xa0–\xa0Longwood, FL', '\xa0–\xa0Lake Buena Vista, FL',
#        '\xa0–\xa0Kissimmee, FL', '\xa0–\xa0Maitland, FL',
#        '\xa0–\xa0Winter Park, FL', '\xa0–\xa0Tampa, FL',
#        '\xa0–\xa0Saint Petersburg, FL', '\xa0–\xa0Temple Terrace, FL',
#        '\xa0–\xa0Houston, TX', '\xa0–\xa0Colorado Springs, CO',
#        '\xa0–\xa0Fort Carson, CO', '\xa0–\xa0Virginia Beach, VA',
#        '\xa0–\xa0Hampton, VA', '\xa0–\xa0Norfolk, VA',
#        '\xa0–\xa0Portsmouth, VA', '\xa0–\xa0Chesapeake, VA'], dtype=object)

# %%
df.shape
# Out:
# (1085, 9)

# %%
df.describe()
# Out:
#         Unnamed: 0  Company_Rating  Location_Code
# count  1085.000000     1020.000000   1.085000e+03
# mean    543.000000        3.662255   1.143141e+06
# std     313.356825        0.567207   8.073385e+03
# min       1.000000        1.000000   1.128808e+06
# 25%     272.000000        3.300000   1.136950e+06
# 50%     543.000000        3.600000   1.145013e+06
# 75%     814.000000        4.000000   1.149603e+06
# max    1085.000000        5.000000   1.155583e+06

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# URL                  object
# Description          object
# Job_Title            object
# Company_Rating      float64
# Company_Name         object
# Company_Location     object
# Estimated_Salary     object
# Location_Code         int64
# dtype: object

# %%
# Calculate the percentage of missing data for each column
missing_percentage = df.isnull().mean() * 100

# Display the percentage of missing data
print(missing_percentage)
# Out:
# Unnamed: 0           0.000000
# URL                  0.000000
# Description          0.552995
# Job_Title            3.594470
# Company_Rating       5.990783
# Company_Name         5.345622
# Company_Location     6.175115
# Estimated_Salary    28.387097
# Location_Code        0.000000
# dtype: float64
